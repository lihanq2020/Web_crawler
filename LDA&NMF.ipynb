# %%
import pandas as pd
import numpy as np
import scipy as sp
import sklearn
from gensim.models import ldamodel
import gensim.corpora
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import NMF
from sklearn.preprocessing import normalize
import pickle

# %%
with open('data/stop_words.txt', 'r') as f:
    stopwords = [line.strip() for line in f]
stopwords += [' ', '的', '是', ',', '。', '_', '-', '、', '，', '“', '”', '.', '》', '《', '']

# %%
data = []
with open('data/n_output.txt', 'r') as f:
    for line in f:
        text = [x.strip() for x in line.split(' ') if x not in stopwords]
        data.append(text)

# %%
num_topics = 10

# %%
id2word = gensim.corpora.Dictionary(data)
corpus = [id2word.doc2bow(text) for text in data]
lda = ldamodel.LdaModel(corpus=corpus, id2word=id2word, num_topics=num_topics)

# %%
def get_lda_topics(model, num_topics):
    word_dict = {}
    for i in range(num_topics):
        words = model.show_topic(i, topn = 20)
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words]
    return pd.DataFrame(word_dict)

# %%
get_lda_topics(lda, num_topics)
# Out:
#    Topic # 01 Topic # 02 Topic # 03 Topic # 04 Topic # 05 Topic # 06  \
# 0           ～          。          了          ？         喜欢         dw
# 1           爱          粉         rs          说          吗         xw
# 2           [          楼         蓝海          黑          会          。
# 3           ]          惹          啊          踩        dxw          说
# 4           ·          快          太         麻袋          唱         没有
# 5           （         wf         真的          掐          想         一个
# 6           ）          红         声音         水产          说         现在
# 7           ！          肝         真是         属性          ？         粉丝
# 8           么         反正         恶心          买          听         公司
# 9          你家         镜头          死          贴        low          没
# 10         不要         qj         人气          狗         希望         组合
# 11         锤子         qq          没         知道         一个         觉得
# 12         哭哭          找          笑         kw         真的         cp
# 13         纸鸟         以后          哭          没         一起         kj
# 14         他家         智商         看到          呢         屠夫          站
# 15          求         KJ         已经         到底         知道         yj
# 16          挑         麻袋          ，          圈          歌         微博
# 17          道         楼主         简直         合唱         觉得          会
# 18         队长          炸          偏         微博         难道         不要
# 19         好好         尴尬          锤         XW         唱歌         gg
#
#    Topic # 07 Topic # 08 Topic # 09 Topic # 10
# 0           —          …          =         觉得
# 1           ！          -          ~          说
# 2           ;          :        哈哈哈          。
# 3          &#          转          【          的
# 4           &         转发          】         感觉
# 5           @       http         48          没
# 6           年         唯饭         DW          挺
# 7          好听         美帝          咯         喜欢
# 8          期待         rr         图片         真的
# 9          肝肝          唯         截图         视频
# 10         10         销量         加油         gs
# 11         至少          婊         掐架         一个
# 12          %          帮       哈哈哈哈         好看
# 13         部分        后花园          酸         不错
# 14       mder          q        练习生         看到
# 15          瞎      baidu         最美         腿姐
# 16          –          主       solo          会
# 17          删         不够         产品         现在
# 18          人         西皮          轮         其实
# 19         身高      tieba         wb         好像

# %%
train_sentences = [' '.join(text) for text in data]

# %%
vectorizer = CountVectorizer(analyzer='word', max_features=5000)
x_counts = vectorizer.fit_transform(train_sentences)

# %%
transformer = TfidfTransformer(smooth_idf=False)
x_tfidf = transformer.fit_transform(x_counts)

# %%
xtfidf_norm = normalize(x_tfidf, norm='l1', axis=1)

# %%
#obtain a NMF model.
model = NMF(n_components=num_topics, init='nndsvd');
#fit the model
model.fit(xtfidf_norm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init='nndsvd', l1_ratio=0.0,
#   max_iter=200, n_components=10, random_state=None, shuffle=False,
#   solver='cd', tol=0.0001, verbose=0)

# %%
def get_nmf_topics(model, n_top_words):
    
    #the word ids obtained need to be reverse-mapped to the words so we can print the topic names.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(num_topics):
        
        #for each topic, obtain the largest values, and add the words they map to into the dictionary.
        words_ids = model.components_[i].argsort()[:-20 - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
get_nmf_topics(model, 20)
# Out:
#    Topic # 01 Topic # 02 Topic # 03 Topic # 04 Topic # 05 Topic # 06  \
# 0         哈哈哈         xw         图片         真的         dw         喜欢
# 1          哈哈         gg         一下         觉得         gg         感觉
# 2          可爱         可爱         看到         知道         知道         觉得
# 3          卧槽         觉得         可怕         感觉         觉得         知道
# 4          搞笑         感觉         知道         现在         现在         这种
# 5          好笑         今天         微博         gg         今天         楼主
# 6          尴尬         看到         今天         看到         感觉         现在
# 7        xswl         知道         真是         不要         不要         gg
# 8          妈呀         真是         这是         可爱         看到         特别
# 9          真是         应该         感觉         不会         不会         这张
# 10         楼主        是不是         看看         好像        是不是         其实
# 11         我要         希望         应该         可能         微博         可爱
# 12         看到         一直         有点         今天         一下         比较
# 13         今天         现在         已经         恶心         真是         cp
# 14         不要         衣服         gg         希望         一直         不要
# 15         感觉         微博         可爱         不错         楼主         希望
# 16       红红火火         不要         百度         有点         有点         以前
# 17         有毒         不会         这张         一下         应该         不会
# 18         心疼         好像         相册         麻袋         可能         一直
# 19         表情         声音         cp         厉害         粉丝         看到
#
#    Topic # 07 Topic # 08 Topic # 09 Topic # 10
# 0          一个         好看         没有       哈哈哈哈
# 1          知道         觉得         楼主         知道
# 2          觉得         今天         知道         看到
# 3          楼主         衣服         现在         可爱
# 4          看到        dxw         觉得         楼主
# 5          现在         感觉         今天         卧槽
# 6          不会         gg         感觉         搞笑
# 7          不要         现在         不要        好好笑
# 8          感觉         长得         看到         好像
# 9          两个         眼睛         gg         真是
# 10         麻袋         不错         麻袋         不要
# 11         不能         有点         一点         努力
# 12         gg         这张         不会         觉得
# 13         可能        啊啊啊         cp         好笑
# 14         今天         其实         粉丝         gg
# 15        是不是         一点         直播         尴尬
# 16         组合         看到         应该         我要
# 17         最后         推荐         已经         开心
# 18         一下         真是         好像         麻袋
# 19         真是         发型         微博         一下
